# %% [markdown]
# Movie Genres Data Analysis

# %% [markdown]
# ### Research Questions (Q):
# 1. Which genres are the most common (number of movies made)?
# 2. Which genres have high avg. budget and revenue?
# 2.5. Which genres have high avg. profit?
# 3. Which genres have high avg. popularity?
# 4. Which genres have highest number of movies with an voting avg. >= 8?

# %%
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\GIA DAT\OneDrive\Documents\Online study\Pandas\Project\imdb_movies.csv')
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
pd.set_option('display.max.rows', 11000)
pd.set_option('display.max.columns', 22)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10842 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10842 non-null  int64
#  1   imdb_id               10834 non-null  object
#  2   popularity            10842 non-null  float64
#  3   budget                10842 non-null  int64
#  4   revenue               10842 non-null  int64
#  5   original_title        10842 non-null  object
#  6   cast                  10767 non-null  object
#  7   homepage              2931 non-null   object
#  8   director              10800 non-null  object
#  9   tagline               8036 non-null   object
#  10  keywords              9367 non-null   object
#  11  overview              10839 non-null  object
#  12  runtime               10842 non-null  int64
#  13  genres                10842 non-null  object
#  14  production_companies  9826 non-null   object
# ...

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movies[movies.duplicated()]
# Out:
#          id    imdb_id  popularity    budget  revenue original_title  \
# 2090  42194  tt0411951     0.59643  30000000   967000         TEKKEN
#
#                                                    cast homepage  \
# 2090  Jon Foo|Kelly Overton|Cary-Hiroyuki Tagawa|Ian...      NaN
#
#               director              tagline  ...  \
# 2090  Dwight H. Little  Survival is no game  ...
#
#                                                overview runtime  \
# 2090  In the year of 2039, after World Wars destroy ...      92
#
#                                            genres    production_companies  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction  Namco|Light Song Films
#
#      release_date vote_count  vote_average  release_year  budget_adj  \
# 2090      3/20/10        110           5.0          2010  30000000.0
#
#       revenue_adj
# 2090     967000.0
#
# [1 rows x 21 columns]

# %%
movies.dropna(subset = ['genres'], inplace = True)

# %%
movies['profit'] = movies['revenue'] - movies['budget']

# %%
movies_genre = movies[['popularity', 'budget', 'revenue', 'original_title', 'runtime', 'genres', 'release_year', 'vote_count', 'vote_average', 'profit']]

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres  release_year  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller          2015        5562
# 1  Action|Adventure|Science Fiction|Thriller          2015        6185
# 2         Adventure|Science Fiction|Thriller          2015        2480
# 3   Action|Adventure|Science Fiction|Fantasy          2015        5292
# 4                      Action|Crime|Thriller          2015        2947
#
#    vote_average      profit
# 0           6.5  1363528810
# ...

# %% [markdown]
# Which genres are the most common (number of movies made)?

# %%
from pandas import Series, DataFrame

# %%
split = movies_genre['genres'].str.split('|').apply(Series, 1).stack()
split.index = split.index.droplevel(-1)
split.name = 'genres_split'
del movies_genre['genres']
movies_genre = movies_genre.join(split)
# Out:
# C:\Users\GIA DAT\AppData\Local\Temp\ipykernel_11812\237449120.py:1: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   split = movies_genre['genres'].str.split('|').apply(Series, 1).stack()

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#    release_year  vote_count  vote_average      profit     genres_split
# 0          2015        5562           6.5  1363528810           Action
# 0          2015        5562           6.5  1363528810        Adventure
# 0          2015        5562           6.5  1363528810  Science Fiction
# 0          2015        5562           6.5  1363528810         Thriller
# 1          2015        6185           7.1   228436354           Action

# %%
genres_count = pd.DataFrame(movies_genre.groupby('genres_split')['original_title'].count().sort_values(ascending = False))
genres_count
# Out:
#                  original_title
# genres_split
# Drama                      4760
# Comedy                     3793
# Thriller                   2907
# Action                     2384
# Romance                    1712
# Horror                     1637
# Adventure                  1471
# Crime                      1354
# Family                     1231
# Science Fiction            1229
# Fantasy                     916
# Mystery                     810
# Animation                   699
# Documentary                 520
# Music                       408
# History                     334
# War                         270
# Foreign                     188
# TV Movie                    167
# Western                     165

# %%
genres_count['original_title'].plot.pie(title = 'Movies Per Genre in %', autopct = '%1.1f%%', figsize = (10, 10))
# Out:
# <Axes: title={'center': 'Movies Per Genre in %'}, ylabel='original_title'>

# %%
genres_count['original_title'].sort_values(ascending = True).plot.barh(title = 'Movies per Genre', color = 'DarkBlue', figsize = (10, 9))
# Out:
# <Axes: title={'center': 'Movies per Genre'}, ylabel='genres_split'>

# %% [markdown]
# Which genres have high avg. budget and revenue?

# %%
genres_avg = movies_genre.groupby('genres_split').mean(numeric_only = True)
pd.options.display.float_format = '{:2f}'.format

genres_avg
# Out:
#                  popularity          budget          revenue    runtime  \
# genres_split
# Action             0.926274 27727820.331376  72794732.002517 104.917785
# Adventure          1.154259 37543694.530931 113137861.069341 106.173351
# Animation          0.852182 23159781.606581  75256062.223176  68.181688
# Comedy             0.592607 13297915.618244  37526242.072238  96.745057
# Crime              0.744930 17663801.124815  42368661.645495 106.917282
# Documentary        0.181432   577149.148077   2041106.994231 102.651923
# Drama              0.591495 11880717.773529  29232255.725840 110.478151
# Family             0.786668 23359337.420796  72433176.373680  89.603574
# Fantasy            0.992840 32612585.348253  96313657.081878 100.736900
# Foreign            0.191496  1451434.925532   1520459.835106 107.228723
# History            0.575936 18594919.302395  32011793.215569 136.206587
# Horror             0.465357  6226529.210751  16822808.624313  94.424557
# ...

# %%
genres_avg.sort_values('profit', ascending = True, inplace = True)

# %%
genres_avg['profit'].plot.barh(title = 'Profit', color = 'DarkBlue', figsize = (10, 9))
# Out:
# <Axes: title={'center': 'Profit'}, ylabel='genres_split'>

# %% [markdown]
# Which genres have high avg. popularity?

# %%
genres_avg.sort_values('popularity', ascending = True, inplace = True)

# %%
genres_avg['popularity'].plot.barh(title = 'Popularity', color = 'DarkBlue', figsize = (10, 9))
# Out:
# <Axes: title={'center': 'Popularity'}, ylabel='genres_split'>

# %% [markdown]
# Which genres have highest number of movies with an voting avg. >= 8?

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#   release_date  vote_count  vote_average      profit     genres_split
# 0       6/9/15        5562      6.500000  1363528810           Action
# 0       6/9/15        5562      6.500000  1363528810        Adventure
# 0       6/9/15        5562      6.500000  1363528810  Science Fiction
# 0       6/9/15        5562      6.500000  1363528810         Thriller
# 1      5/13/15        6185      7.100000   228436354           Action

# %%
vote_fifty = movies_genre[(movies_genre['vote_count'] >= 50) & (movies_genre['vote_average'] >= 8)]

# %%
genres_vote = pd.DataFrame(vote_fifty.groupby('genres_split')['vote_average'].nunique()).sort_values(by = 'vote_average', ascending = False)

# %%
genres_vote
# Out:
#                  vote_average
# genres_split
# Documentary                 5
# Drama                       5
# Crime                       4
# Action                      2
# History                     2
# Thriller                    2
# Romance                     2
# Music                       2
# War                         2
# Adventure                   2
# Comedy                      2
# Horror                      1
# Family                      1
# Mystery                     1
# Science Fiction             1
# Animation                   1
# Fantasy                     1

# %%
genres_vote['vote_average'].plot.barh(title = 'Vote Average', color = 'DarkBlue', figsize = (10, 9))
# Out:
# <Axes: title={'center': 'Vote Average'}, ylabel='genres_split'>

# %% [markdown]
# ### Research Hypothesis (H):
# 1. The best movies according to vote avg. return high profit and revenue.
# 2. The best movies according to popularity return high profit and revenue.
# 3. Highly budgeted movies return high revenue and profit
# 4. Highly budgeted movies have a high popularity

# %%
movies.drop_duplicates(inplace = True)
movies['profit'] = movies['revenue'] - movies['budget']
movies_genre = movies[['popularity', 'budget', 'revenue', 'original_title', 'runtime', 'genres', 'release_date', 'vote_count', 'vote_average', 'profit']]

# %%
movies_counted = movies_genre[movies_genre['vote_count'] >= 50]

movies_counted.corr(method = 'spearman', numeric_only = True)
# Out:
#               popularity    budget  revenue  runtime  vote_count  \
# popularity      1.000000  0.485149 0.588739 0.230518    0.768966
# budget          0.485149  1.000000 0.714828 0.360230    0.554586
# revenue         0.588739  0.714828 1.000000 0.341707    0.682656
# runtime         0.230518  0.360230 0.341707 1.000000    0.263460
# vote_count      0.768966  0.554586 0.682656 0.263460    1.000000
# vote_average    0.188670 -0.044440 0.111731 0.285514    0.284470
# profit          0.498117  0.334390 0.842221 0.212060    0.583602
#
#               vote_average   profit
# popularity        0.188670 0.498117
# budget           -0.044440 0.334390
# revenue           0.111731 0.842221
# runtime           0.285514 0.212060
# vote_count        0.284470 0.583602
# vote_average      1.000000 0.198308
# profit            0.198308 1.000000

# %%
import seaborn as sns

sns.regplot(x = 'vote_average', y = 'revenue', data = movies_counted, line_kws = {'color' : 'red'})
# Out:
# <Axes: xlabel='vote_average', ylabel='revenue'>

# %%
import matplotlib.pyplot as plt

sns.regplot(x = 'popularity', y = 'revenue', data = movies_counted, line_kws = {'color' : 'red'})
# Out:
# <Axes: xlabel='popularity', ylabel='revenue'>

# %%
sns.regplot(x = 'budget', y = 'profit', data = movies_counted, line_kws = {'color' : 'red'})
# Out:
# <Axes: xlabel='budget', ylabel='profit'>

# %%
sns.regplot(x = 'budget', y = 'popularity', data = movies_counted, line_kws = {'color' : 'red'})
# Out:
# <Axes: xlabel='budget', ylabel='popularity'>

# %% [markdown]
# 5. Take a look at Profit Per Genre Per Year

# %%
movies_genre.head()
# Out:
#    popularity     budget     revenue      original_title  runtime  \
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 0   32.985763  150000000  1513528810      Jurassic World      124
# 1   28.419936  150000000   378436354  Mad Max: Fury Road      120
#
#    release_year  vote_count  vote_average      profit     genres_split
# 0          2015        5562      6.500000  1363528810           Action
# 0          2015        5562      6.500000  1363528810        Adventure
# 0          2015        5562      6.500000  1363528810  Science Fiction
# 0          2015        5562      6.500000  1363528810         Thriller
# 1          2015        6185      7.100000   228436354           Action

# %%
time_genre = pd.DataFrame(movies_genre.groupby(['release_year', 'genres_split'])['profit'].mean())
time_genre
# Out:
#                                        profit
# release_year genres_split
# 1960         Action            6363125.000000
#              Adventure          431000.000000
#              Comedy            5258750.000000
#              Crime                   0.000000
#              Drama             8245619.384615
#              Family            3333333.333333
#              Fantasy           -375000.000000
#              Foreign                 0.000000
#              History           9600000.000000
#              Horror            4389007.428571
#              Music                   0.000000
#              Romance           5225000.000000
#              Science Fiction   -316666.666667
#              Thriller          5028842.000000
#              War                     0.000000
#              Western            484166.666667
# 1961         Action            2457142.857143
#              Adventure        39130002.333333
#              Animation       211880014.000000
# ...

# %%
final_genre = pd.pivot_table(time_genre, values = 'profit', index = ['genres_split'], columns = ['release_year'])

# %%
sns.set(rc = {'figure.figsize': (15, 10)})
sns.heatmap(final_genre, cmap = 'coolwarm', linewidths = 0.5)
plt.title('Genres by Profit by Year')
# Out:
# Text(0.5, 1.0, 'Genres by Profit by Year')

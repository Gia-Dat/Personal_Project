# %% [markdown]
# Unit of Measurement Converter

# %%
convert_from = input("Enter Starting Unit of Measurement(inches,feet,yards): ")

convert_to = input("Enter Unit of Measurement to convert to(inches,feet,yards): ")

number_of_inches = input("Enter Starting Measurement in Inches: ")

number_of_feet = input("Enter Starting Measurement in Feet: ")

number_of_yards = input("Enter Starting Measurement in Yards: ")
# Out:
# Enter Starting Unit of Measurement(inches,feet,yards):  inches
# Enter Unit of Measurement to convert to(inches,feet,yards):  feet
# Enter Starting Measurement in Inches:  24
# Enter Starting Measurement in Feet:  3
# Enter Starting Measurement in Yards:  1

# %%
convert_from = input("Enter Starting Unit of Measurement(inches,feet,yards): ")

convert_to = input("Enter Unit of Measurement to convert to(inches,feet,yards): ")

if convert_from.lower() in "inches":
    number_of_inches = int(input("Enter Starting Measurement in Inches: "))
    if convert_to.lower() in 'feet':
        print("Result:", number_of_inches, "Inch = ", number_of_inches/12, "Feet")
    elif convert_to.lower() in 'yards':
        print("Result:", number_of_inches, "Inch = ", number_of_inches/36, "Yard")
    else:
        print("Please Enter either Feet, or Yards.")
elif convert_from.lower() in "feet":
    number_of_feet = int(input("Enter Starting Measurement in Feet: "))
    if convert_to.lower() in "inches":
        print("Result:", number_of_feet, "Feet = ", number_of_feet*12, "Inch")
    elif convert_to.lower() in 'yards':
        print("Result:", number_of_feet, "Feet = ", number_of_inches/3, "Yard")
    else:
        print("Please Enter either Inches, or Yards.")
elif convert_from.lower() in "yards":
    number_of_yards = int(input("Enter Starting Measurement in Yards: "))
    if convert_to.lower() in "inches":
        print("Result:", number_of_yards, "Yard = ", number_of_yards*36, "Inch")
    elif convert_to.lower() in 'feet':
        print("Result:", number_of_yards, "Yard = ", number_of_yards*3, "Feet")
    else:
        print("Please Enter either Inches, or Feet.")    
else:
    print("Please Enter either Inches, Feet, or Yards.")
# Out:
# Enter Starting Unit of Measurement(inches,feet,yards):  ya
# Enter Unit of Measurement to convert to(inches,feet,yards):  fe
# Enter Starting Measurement in Yards:  45
# Result: 45 Yard =  135 Feet
